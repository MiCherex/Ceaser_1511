# %%
import math
chisla=[]
raz=[]
naim=[]
def mnogitely(n):
   mnog=[]
   while n % 2 == 0 and n!=0:
      mnog.append(2)
      n = n / 2
   for i in range(3,int(n+1),2):
      while (n % i == 0) and (n!=0):
         mnog.append(i)
         n = n / i
   return(mnog)
a=100000
b=600000
for i in range(a, b+1):
  c=mnogitely(i)
  if (len(c)==3) and (c[0]!=c[1] and c[0]!=c[2] and c[1]!=c[2]) and(c[0]%10==c[2]%10==c[1]%10):
    chisla.append([i,c[2]-c[0]])
for j in range(0, len(chisla)):
  raz.append(chisla[j][1])  
  mini=max(raz)
  
for k in range(0, len(raz)):
  if raz[k]==mini:
    naim.append(chisla[k][0])
    vivod=min(naim)
g=str(chisla)
if '[]'==g:
 print(0)
 print(0)
print(len(chisla))
print(vivod)
# Out:
# 2576
# 599937

# %%
chisla=[]
b=str(chisla)
if '[]'==b:
 print(1)
# Out:
# 1
