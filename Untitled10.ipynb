# %%
a=-3000
b=-987

maxnum=[]
count=[int(0)]

# %%
a=int(input())
b=int(input())

maxnum=[]
count=[int(0)]
def check(number,maxnum,count):

  if (number//10!=0):
    num=number 
    num2=number
    countRaz=int(0)
    while(number>0):
	    countRaz=countRaz+1
	    number=number//10
    raz=str(num)
    n2=int(raz[0]+raz[1])
    n1=int(raz[countRaz-2]+raz[countRaz-1])
    if n1!=n2:
      if(num%(n1-n2)==0):
        maxnum.append(num)
        count[0]=count[0]+1
       
        
for i in range(a, b+1):

  check(i,maxnum,count)

print(len(maxnum))
print(max(maxnum))
# Out:
# 1
# 1
# 100

# %%
for i in range(a, b+1):

  check(i,maxnum,count)
print(count[0])
print(len(maxnum))
print(max(maxnum))
# Out:
# 1273
# 1273
# -990

# %%
raz=str(1234)
countRaz=4
n2=int(raz[0]+raz[1])
n1=(raz[countRaz-2]+raz[countRaz-1])
print(n1)
print(n2)
# Out:
# 34
# 12
